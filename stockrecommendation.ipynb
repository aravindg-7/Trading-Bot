# %%
import numpy as np
import pandas as pd
import math
from scipy import stats
from statistics import mean
import requests
import xlsxwriter

# %%
stocks = pd.read_csv('sp500_stocks.csv')
from api_key import IEX_CLOUD_API_TOKEN

# %%
stocks
# Out:
#     Symbol
# 0     AAPL
# 1     MSFT
# 2     GOOG
# 3    GOOGL
# 4     AMZN
# ..     ...
# 498    VNO
# 499   PENN
# 500    ALK
# 501    PVH
# 502   NCLH
#
# [503 rows x 1 columns]

# %%
def batch(lst,size):
    symbol_group = []
    for i in range(0,len(lst),size):
        symbol_group.append(lst[i:i+size])       
    return symbol_group

# %%
symbol_group = batch(stocks['Symbol'],100)
symbol_strings = []
for i in range(len(symbol_group)):
    symbol_strings.append(','.join(symbol_group[i]))

# %%
column_names = ['Symbol','Price','Price to Earnings Ratio','PE Percentile','Price to Book Ratio','PB Percentile',
                'Price to Sales Ratio', 'PS Percentile','EV/EBITDA', 'EV/EBITDA Percentile',
                'EV/GP','EV/GP Percentile','Score', 'No.of Shares to Buy']
df = pd.DataFrame(columns = column_names)
for symbols in symbol_strings:
    batch_api = f'https://sandbox.iexapis.com/stable//stock/market/batch?symbols={symbols}&types=advanced-stats,price&token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(batch_api).json()
#     print(data)
    for s in symbols.split(','):
        ev = data[s]['advanced-stats']['enterpriseValue']
        ebitda = data[s]['advanced-stats']['EBITDA']
        if ev and ebitda:
            ev_to_ebitda = ev/ebitda
        else:
            ev_to_ebitda = np.NaN
        if ev and gp:
            ev_to_gp = ev/gp
        else:
            ev_to_gp = np.NaN
        gp = data[s]['advanced-stats']['grossProfit']
        df = df.append(pd.Series([s,data[s]['price'],data[s]['advanced-stats']['peRatio'],'N/A',
                                  data[s]['advanced-stats']['priceToBook'],'N/A',
                                  data[s]['advanced-stats']['priceToSales'],'N/A',
                                  ev_to_ebitda,'N/A',
                                  ev_to_gp,'N/A','N/A','N/A'],index = column_names),ignore_index=True)

# %%
cnames = ['Price','Price to Earnings Ratio','Price to Book Ratio', 'Price to Sales Ratio','EV/EBITDA', 'EV/GP']
for col in cnames:
    df[col].fillna(df[col].mean(),inplace = True)

# %%
percentile = {
    'Price to Earnings Ratio':'PE Percentile',
    'Price to Book Ratio':'PB Percentile',
    'Price to Sales Ratio':'PS Percentile',
    'EV/EBITDA':'EV/EBITDA Percentile',
    'EV/GP':'EV/GP Percentile'
}
for row in df.index:
    values = []
    for key in percentile:
        df.loc[row,percentile[key]] = stats.percentileofscore(df[key],df.loc[row,key])
        values.append(df.loc[row,percentile[key]])
    df.loc[row,'Score'] = mean(values)

df
# Out:
#     Symbol   Price  Price to Earnings Ratio PE Percentile  \
# 0     AAPL  162.61                26.015089     60.039761
# 1     MSFT  287.31                29.196248     68.190855
# 2     GOOG  122.01                26.138930     61.332008
# 3    GOOGL  119.63                 1.044209      3.578529
# 4     AMZN  141.58                60.521221     93.439364
# ..     ...     ...                      ...           ...
# 498    VNO   31.34                48.701409     89.860835
# 499   PENN   35.90                15.070439     31.212724
# 500    ALK   45.22                12.319457     23.459245
# 501    PVH   62.70                 4.268980      4.771372
# 502   NCLH   12.26                -0.654113      3.379722
#
#      Price to Book Ratio PB Percentile  Price to Sales Ratio PS Percentile  \
# 0              38.930000     97.017893               6.90000     83.399602
# 1              13.300000     90.457256              10.83000     92.047714
# 2               3.960788     58.151093               4.17451     67.296223
# 3               0.311000      6.560636               0.29740       1.39165
# 4               9.360000     82.803181               2.70000     45.924453
# ..                   ...           ...                   ...           ...
# 498             1.190000     12.524851               3.64000      59.44334
# 499             1.470000     18.489066               0.95330     13.518887
# 500             1.580000     20.775348               0.80000     10.337972
# 501             0.797300      8.548708               0.45190      3.578529
# 502             1.770000     24.254473               2.26000     38.767396
#
#      EV/EBITDA EV/EBITDA Percentile        EV/GP EV/GP Percentile      Score  \
# 0    19.333893            69.582505  4311.376903            100.0  82.007952
# 1    21.390007            74.751491    11.954539        75.944334   80.27833
# 2    36.590149             94.73161    17.046603        89.761431  74.254473
# 3    -0.436877              1.39165    17.046603        89.761431  20.536779
# 4    24.004569             82.50497     8.399210        62.425447  73.419483
# ..         ...                  ...          ...              ...        ...
# 498  14.926076             53.87674     4.244198        29.224652  48.986083
# 499   6.658784            13.916501     6.370316        44.930417  24.413519
# 500   8.566614            24.254473     1.766211         9.145129  17.594433
# 501   4.503777             5.765408     0.779292         2.186879   4.970179
# 502  -7.300659             1.192843     2.665909        15.705765   16.66004
#
#     No.of Shares to Buy
# 0                   N/A
# 1                   N/A
# 2                   N/A
# 3                   N/A
# 4                   N/A
# ..                  ...
# 498                 N/A
# 499                 N/A
# 500                 N/A
# 501                 N/A
# 502                 N/A
#
# [503 rows x 14 columns]

# %% [markdown]
# Choosing the least value stocks

# %%
df.sort_values('Score',inplace = True)

# %%
df = df[0:30]
df
# Out:
#    Symbol   Price  Price to Earnings Ratio PE Percentile  Price to Book Ratio  \
# 0     PVH   62.70                 4.268980      4.771372               0.7973
# 1     PRU  104.69                 7.899891     11.928429               0.8672
# 2     ALL  119.67                 9.202065     15.506958               1.5000
# 3     LNC   51.78                 6.752093      9.940358               0.6183
# 4     HIG   64.51                 8.356466     13.518887               1.3600
# 5     DXC   32.80                10.604271     19.681909               1.4900
# 6    PARA   24.47                 3.931837       4.17495               0.7330
# 7      RE  265.85                 8.062907     12.326044               1.1100
# 8     COF  113.61                 3.985337      4.373757               0.7827
# 9     AIZ  182.27                 7.140082     10.536779               1.8700
# 10     GM   37.40                 6.790743     10.139165               0.8481
# 11    HPQ   34.09                 5.527327      7.554672             -18.1700
# 12      T   19.33                 8.097879     12.723658               0.7923
# 13   CINF  101.04                 7.727871     11.530815               1.3200
# 14     GS  346.84                 6.292915      8.747515               1.0800
# 15    LEN   85.00                 5.718549      7.952286               1.1400
# 16    HPE   14.39                 4.989392      6.560636               0.8970
# 17    TAP   60.60                12.105558     22.862823               0.9522
# 18    UHS  117.72                10.296615     18.687873               1.6300
# 19    TRV  164.50                10.679644      20.27833               1.6800
# 20   NCLH   12.26                -0.654113      3.379722               1.7700
# 21    WHR  178.68                13.877702     27.634195               2.4500
# 22    APA   38.62                 4.924611      6.361829            -686.5800
# 23   ZION   55.51                 5.330897      7.355865               1.4400
# 24    SYF   34.03                 4.335876      5.367793               1.3000
# 28             5.964215  7.107373        51.093439  17.733598
# 29            16.500994  5.682281        39.960239  17.793241
#
#    No.of Shares to Buy
# 0                  N/A
# 1                  N/A
# 2                  N/A
# 3                  N/A
# 4                  N/A
# 5                  N/A
# 6                  N/A
# 7                  N/A
# 8                  N/A
# 9                  N/A
# 10                 N/A
# 11                 N/A
# 12                 N/A
# 13                 N/A
# 14                 N/A
# 15                 N/A
# 16                 N/A
# 17                 N/A
# 18                 N/A
# 19                 N/A
# 20                 N/A
# 21                 N/A
# 22                 N/A
# 23                 N/A
# 24                 N/A
# 25                 N/A
# 26                 N/A
# 27                 N/A
# 28                 N/A
# 29                 N/A

# %%
def invest():
    flag = True
    while(flag):
        amount = input('Enter your investment in dollars\n')
        try:
            val = float(amount)
        except ValueError:
            print('Investment accepts only numbers try again\n')
        else:
            flag = False
    return float(amount)

# %%
investment = invest()
# Out:
# Enter your investment in dollars
# 300000

# %%
investment_size = investment/len(df.index)
investment_size
# Out:
# 10000.0

# %%
for row in df.index:
    df.loc[row,'No.of Shares to Buy'] = math.floor(investment_size/df.loc[row,'Price'])

# %%
df
# Out:
#    Symbol   Price  Price to Earnings Ratio PE Percentile  Price to Book Ratio  \
# 0     PVH   62.70                 4.268980      4.771372               0.7973
# 1     PRU  104.69                 7.899891     11.928429               0.8672
# 2     ALL  119.67                 9.202065     15.506958               1.5000
# 3     LNC   51.78                 6.752093      9.940358               0.6183
# 4     HIG   64.51                 8.356466     13.518887               1.3600
# 5     DXC   32.80                10.604271     19.681909               1.4900
# 6    PARA   24.47                 3.931837       4.17495               0.7330
# 7      RE  265.85                 8.062907     12.326044               1.1100
# 8     COF  113.61                 3.985337      4.373757               0.7827
# 9     AIZ  182.27                 7.140082     10.536779               1.8700
# 10     GM   37.40                 6.790743     10.139165               0.8481
# 11    HPQ   34.09                 5.527327      7.554672             -18.1700
# 12      T   19.33                 8.097879     12.723658               0.7923
# 13   CINF  101.04                 7.727871     11.530815               1.3200
# 14     GS  346.84                 6.292915      8.747515               1.0800
# 15    LEN   85.00                 5.718549      7.952286               1.1400
# 16    HPE   14.39                 4.989392      6.560636               0.8970
# 17    TAP   60.60                12.105558     22.862823               0.9522
# 18    UHS  117.72                10.296615     18.687873               1.6300
# 19    TRV  164.50                10.679644      20.27833               1.6800
# 20   NCLH   12.26                -0.654113      3.379722               1.7700
# 21    WHR  178.68                13.877702     27.634195               2.4500
# 22    APA   38.62                 4.924611      6.361829            -686.5800
# 23   ZION   55.51                 5.330897      7.355865               1.4400
# 24    SYF   34.03                 4.335876      5.367793               1.3000
# 25     IP   44.35                 9.430059     16.302187               1.8100
# 26    AIG   54.35                 4.200695      4.572565               0.7355
# 27    ALK   45.22                12.319457     23.459245               1.5800
# 28    MET   63.35                 7.792631     11.729622               0.9720
# 29    IVZ   17.97                 6.006408      8.349901               0.5207
#
#    PB Percentile  Price to Sales Ratio PS Percentile  EV/EBITDA  \
# 0       8.548708                0.4519      3.578529   4.503777
# 1       8.946322                0.5589      5.964215   5.120149
# 2      18.986083                0.6466      7.554672   3.008248
# 3       7.554672                0.4563      3.777336   5.179864
# 4      16.202783                0.9488      13.32008   4.319103
